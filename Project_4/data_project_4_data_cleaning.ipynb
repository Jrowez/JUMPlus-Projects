# %%
"""
Phase 1 (Data Cleaning Phase)
1. Import required libraries
2. Read the csv file
3. Show first five results
4. Show if columns have any NaN,N/A or null values in boolean form
5. Check how many null,empty,N/A values are there in each column
6. Show null values of each column with the help of Heatmap
7. Drop outliers (columns which are not useful according to you)
8. Drop the null values containing rows from the object which you created in
point 7
9. Check the dataframe again if there is anything which you want to remove
more.
10. Export dataframe to your desired location with no index column
"""

# %% [markdown]
# Phase 1 (Data Cleaning Phase)

# %%
"""1. Import required libraries"""

import pandas as pd
import os
import seaborn as sns
from matplotlib import pyplot as plt 
import numpy as np

# %%
"""2. Read the csv file"""
raw_df = pd.read_csv('Video_Games_Sales_as_at_22_Dec_2016.csv')
raw_df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
"""3. Show first five results"""
raw_df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count  User_Score  User_Count Developer Rating
# ...

# %%
"""4. Show if columns have any NaN,N/A or null values in boolean form"""

#cleaner version
raw_df.isna().any()

#table format
raw_df.isna()
# Out:
#         Name  Platform  Year_of_Release  Genre  Publisher  NA_Sales  EU_Sales  \
# 0      False     False            False  False      False     False     False
# 1      False     False            False  False      False     False     False
# 2      False     False            False  False      False     False     False
# 3      False     False            False  False      False     False     False
# 4      False     False            False  False      False     False     False
# ...      ...       ...              ...    ...        ...       ...       ...
# 16714  False     False            False  False      False     False     False
# 16715  False     False            False  False      False     False     False
# 16716  False     False            False  False      False     False     False
# 16717  False     False            False  False      False     False     False
# 16718  False     False            False  False      False     False     False
#
# ...

# %%
"""5. Check how many null,empty,N/A values are there in each column"""
raw_df.isnull().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         9129
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %%
raw_df.isna().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         9129
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %%
"""6. Show null values of each column with the help of Heatmap"""
figsize = (10, 5)
fig, ax = plt.subplots(figsize=figsize)
# sns.heatmap(data=raw_df.isna().any())
sns.heatmap(raw_df.isna(), yticklabels=False)
# Out:
# <Axes: >

# %%
"""7. Drop outliers (columns which are not useful according to you)"""

#dropping Critic_Score, Critic_Count, User_Score, User_Count, Developer
df = raw_df.drop(['Critic_Score', 'Critic_Count', 'User_Score', 'User_Count', 'Developer'], axis=1)

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales Rating
# 0     41.36     28.96      3.77         8.45         82.53      E
# 1     29.08      3.58      6.81         0.77         40.24    NaN
# 2     15.68     12.76      3.79         3.29         35.52      E
# 3     15.61     10.93      3.28         2.95         32.77      E
# 4     11.27      8.89     10.22         1.00         31.37    NaN

# %%
"""8. Drop the null values containing rows from the object which you created in point 7"""
clean_df = df.dropna()

# %%
"""9. Check the dataframe again if there is anything which you want to remove"""
clean_df
# Out:
#                                 Name Platform  Year_of_Release       Genre  \
# 0                         Wii Sports      Wii           2006.0      Sports
# 2                     Mario Kart Wii      Wii           2008.0      Racing
# 3                  Wii Sports Resort      Wii           2009.0      Sports
# 6              New Super Mario Bros.       DS           2006.0    Platform
# 7                           Wii Play      Wii           2006.0        Misc
# ...                              ...      ...              ...         ...
# 16701               Bust-A-Move 3000       GC           2003.0      Puzzle
# 16702               Mega Brain Boost       DS           2008.0      Puzzle
# 16706        STORM: Frontline Nation       PC           2011.0    Strategy
# 16708                       Plushees       DS           2008.0  Simulation
# 16710  Men in Black II: Alien Escape       GC           2003.0     Shooter
#
# ...

# %%
"""10. Export dataframe to your desired location with no index column"""

clean_df.to_csv('Video_Games_Sales_22_Dec_2016_Clean', index=False)
