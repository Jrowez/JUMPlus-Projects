# %%
"""
Phase 2 (EDL - Data Analysis Phase)
1. Open new Jupyter notebook
2. Import required libraries
3. Read your cleaned csv which you did in phase 1
4. Shape the data
5. Show first five records
6. Show all columns of the dataframe
7. Show last 5 five rows
8. Describe the data.
9. Group the sales data of each region on Year_of_Release and plot the same
(It should show which region sales was at peak on which year of release)
10. Group North American, Japan, European & Other region sales data as
per Genre and plot it (It should show highest of region according to game
category , ex- NA_Sales is highest in Adventure category , plot kind
should be bar)
11. Group North American, Japan, European & Other region sales data as
per Platform and plot it (Should show sales as per "Platform genre" , plot
kind should be bar )
12. Plot the Sales in all regions as per Platform , you need to create a
boxplot for that which will show the distribution of sales as per platform
13. Find out which Genre games are sold in highest numbers (create a
countplot of seaborn which could do that)
14. Try to find out global sales as per Genre ,(create a barplot of seaborn
for that)
"""

# %%
"""2. Import required libraries"""
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
"""3. Read your cleaned csv which you did in phase 1"""
df = pd.read_csv("Video_Games_Sales_22_Dec_2016_Clean")
df.head(22)
# Out:
#                                             Name Platform  Year_of_Release  \
# 0                                     Wii Sports      Wii           2006.0
# 1                                 Mario Kart Wii      Wii           2008.0
# 2                              Wii Sports Resort      Wii           2009.0
# 3                          New Super Mario Bros.       DS           2006.0
# 4                                       Wii Play      Wii           2006.0
# 5                      New Super Mario Bros. Wii      Wii           2009.0
# 6                                  Mario Kart DS       DS           2005.0
# 7                                        Wii Fit      Wii           2007.0
# 8                             Kinect Adventures!     X360           2010.0
# 9                                   Wii Fit Plus      Wii           2009.0
# 10                            Grand Theft Auto V      PS3           2013.0
# ...

# %%
"""4. Shape the data"""
df.shape
# Out:
# (9767, 11)

# %%
"""5. Show first five records"""
df.head()
# Out:
#                     Name Platform  Year_of_Release     Genre Publisher  \
# 0             Wii Sports      Wii           2006.0    Sports  Nintendo
# 1         Mario Kart Wii      Wii           2008.0    Racing  Nintendo
# 2      Wii Sports Resort      Wii           2009.0    Sports  Nintendo
# 3  New Super Mario Bros.       DS           2006.0  Platform  Nintendo
# 4               Wii Play      Wii           2006.0      Misc  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales Rating
# 0     41.36     28.96      3.77         8.45         82.53      E
# 1     15.68     12.76      3.79         3.29         35.52      E
# 2     15.61     10.93      3.28         2.95         32.77      E
# 3     11.28      9.14      6.50         2.88         29.80      E
# 4     13.96      9.18      2.93         2.84         28.92      E

# %%
"""6. Show all columns of the dataframe"""
print(list(df.columns), len(list(df.columns)))
# Out:
# ['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Rating'] 11

# %%
"""7. Show last 5 five rows"""
df.tail()
# Out:
#                                Name Platform  Year_of_Release       Genre  \
# 9762               Bust-A-Move 3000       GC           2003.0      Puzzle
# 9763               Mega Brain Boost       DS           2008.0      Puzzle
# 9764        STORM: Frontline Nation       PC           2011.0    Strategy
# 9765                       Plushees       DS           2008.0  Simulation
# 9766  Men in Black II: Alien Escape       GC           2003.0     Shooter
#
#                   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 9762                Ubisoft      0.01      0.00       0.0          0.0
# 9763  Majesco Entertainment      0.01      0.00       0.0          0.0
# 9764                Unknown      0.00      0.01       0.0          0.0
# 9765              Destineer      0.01      0.00       0.0          0.0
# 9766             Infogrames      0.01      0.00       0.0          0.0
#
#       Global_Sales Rating
# 9762          0.01      E
# 9763          0.01      E
# ...

# %%
"""8. Describe the data."""
df.describe()
# Out:
#        Year_of_Release     NA_Sales     EU_Sales     JP_Sales  Other_Sales  \
# count      9767.000000  9767.000000  9767.000000  9767.000000  9767.000000
# mean       2007.582369     0.319012     0.183250     0.046473     0.064788
# std           4.101736     0.826168     0.587525     0.242886     0.230057
# min        1985.000000     0.000000     0.000000     0.000000     0.000000
# 25%        2004.000000     0.050000     0.010000     0.000000     0.010000
# 50%        2008.000000     0.120000     0.040000     0.000000     0.020000
# 75%        2010.000000     0.300000     0.150000     0.000000     0.050000
# max        2020.000000    41.360000    28.960000     6.500000    10.570000
#
#        Global_Sales
# count   9767.000000
# mean       0.613770
# std        1.674662
# min        0.010000
# 25%        0.080000
# 50%        0.210000
# 75%        0.570000
# max       82.530000

# %%
"""9. Group the sales data of each region on Year_of_Release and plot the same
(It should show which region sales was at peak on which year of release)"""

release_sales = df[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Year_of_Release']]
release_sales = release_sales.groupby('Year_of_Release').sum()
release_sales

figsize = (15, 8)
fig, ax = plt.subplots(figsize=figsize)
sns.set_theme(style="whitegrid")
genre = sns.lineplot(data=release_sales, ax=ax, )

# %%
"""10. Group North American, Japan, European & Other region sales data as per Genre and plot it (It should show highest of region according to game
category , ex- NA_Sales is highest in Adventure category , plot kind should be bar)"""

genre_sales = df[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Genre']]
genre_sales = genre_sales.groupby('Genre', as_index=False).sum()
genre_sales

# fig, ax =plt.subplots(figsize=(15,8))
# genre_NA = sns.barplot(x='Genre', y='NA_Sales', data=genre_sales, color='Red')
# genre_EU = sns.barplot(x='Genre', y='EU_Sales', data=genre_sales, color='Blue')
# genre_JP = sns.barplot(x='Genre', y='JP_Sales', data=genre_sales, color='Green')
# genre_Other = sns.barplot(x='Genre', y='Other_Sales', data=genre_sales, color='Purple',)

label_location = np.arange(len(genre_sales))
width = 1
label_multiplier = 0

fig, ax = plt.subplots(layout='none')
for element, measurement in genre_sales.items():
    offset = width * label_multiplier
    rects = ax.bar(label_location + offset, measurement, width, label=element)
    ax.bar_label(rects, padding=3)
    label_multiplier += 0
    
platform = ['Action', 'Adventure', 'Fighting', 'Misc', 'Platform', 'Puzzle', 'Racing', 'Role-Playing', 'Shooter', 'Simulation', 'Sports', 'Strategy']

ax.set_ylabel('Sales (millions)')
ax.set_xlabel('Genre')
ax.set_title('Platform Sales by Region')
ax.set_xticks(label_location + width, platform)
ax.legend(loc='upper left')
ax.set_ylim(0, 650)
#ax.set_xlim(0,100)
plt.show()

# %%
"""11. Group North American, Japan, European & Other region sales data as per Platform and plot 
it (Should show sales as per "Platform genre" , plot kind should be bar )"""

platform_sales = df[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Platform']]
platform_sales = platform_sales.groupby('Platform', as_index=False).sum()
platform_sales

# fig, ax =plt.subplots(figsize=(15,8))
# platform_NA = sns.barplot(x='Platform', y='NA_Sales', data=platform_sales, color='Red')
# platform_EU = sns.barplot(x='Platform', y='EU_Sales', data=platform_sales, color='Blue')
# platform_JP = sns.barplot(x='Platform', y='JP_Sales', data=platform_sales, color='Green')
# platform_Other = sns.barplot(x='Platform', y='Other_Sales', data=platform_sales, color='Purple',)
# ax.set_ylabel('Sales (')
# plt.show

label_location = np.arange(len(platform_sales))
width = 0.25
label_multiplier = 0

fig, ax = plt.subplots(layout='none')
# plt.figure(figsize=(80,10))
for element, measurement in platform_sales.items():
    offset = width * label_multiplier
    rects = ax.bar(label_location + offset, measurement, width, label=element)
    ax.bar_label(rects, padding=3)
    label_multiplier += 1
    
platform = ['3DS', 'DC', 'DS', 'GBA', 'GC', 'PC', 'PS', 'PS2', 'PS3', 'PS4', 'PSP', 'PSV', 'Wii', 'WiiU', 'X360', 'XB', 'XOne']

ax.set_ylabel('Sales (millions)')
ax.set_xlabel('Platform')
ax.set_title('Platform Sales by Region')
ax.set_xticks(label_location + width, platform)
ax.legend(loc='upper left', ncols=20)
ax.set_ylim(0, 650)
ax.set_xlim
plt.show()

# %%
"""12. Plot the Sales in all regions per Platform , you need to create a boxplot for that which will show the distribution of sales as per platform
"""
sns.set_theme(style="whitegrid")
plt.figure(figsize=(15,10))
sns.boxplot(x=df['Year_of_Release'], y=df['Platform'])
plt.xlabel("Release Year")
plt.ylabel("Platform")
plt.show()

# %%
"""13. Find out which Genre games are sold in highest numbers (create a countplot of seaborn which could do that) """
popular_genres = df[['Genre', 'Global_Sales']]
popular_genres = popular_genres.groupby('Genre').count()
popular_genres
sns.set_theme(style="whitegrid")

popular_genres['Genre']= popular_genres.index
plt.figure(figsize=(15,5))
popular_genre_plot = sns.catplot(x='Genre', y='Global_Sales', data=popular_genres, kind='bar')
popular_genre_plot.set_xticklabels(['Action', 'Adventure', 'Fighting', 'Misc', 'Platform', 'Puzzle', 'Racing', 'Role-Playing', 'Shooting', 'Simulation', 'Sports', 'Strategy'], rotation=90)
plt.xlabel("Genre")
plt.ylabel("Total # of Games")
plt.show()


# plt.figure(figsize=(15,10))
# sns.countplot(df['Genre'])
# plt.show()

# %%
"""14. Try to find out global sales as per Genre ,(create a barplot of seaborn for that) """
sales_per_genre = df[['Genre', 'Global_Sales']].groupby('Genre', as_index=False).sum().sort_values('Global_Sales', ascending=False)
sales_per_genre

sns.set_theme(style="whitegrid")
fig, ax = plt.subplots(figsize=(15,8))
sns.barplot(x='Genre', y='Global_Sales', data=sales_per_genre, ax=ax)
# Out:
# <Axes: xlabel='Genre', ylabel='Global_Sales'>
