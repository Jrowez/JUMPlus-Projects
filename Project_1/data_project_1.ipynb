# %%
"""
Data Project 1
1. Load the csv file and show top 5 records from it
2. How would you be able to see each column's name
3. Showw the number of rows and columns in the dataset
4. Show the number of platers in ech country.
5. Create a bar plot of the top 5 countries with the highest number of platers, and fill the bars in green.
6. Display the short name and wages for the top 5 players.
7. Display the short name and wages for the top 5 players with the highest salaries.
8. Create a bar plot of the previous bullet point.
9. Show top 10 records for Germany.
10. Show the top 5 records of Germnay players who have a maximum height, weight, and wage
11. Display the short name and wages of the top 5 Germany players
12. Show top 5 players who have the best shooting skills amoung all the players with short names.
13. Show top 5 platers records (short name, defending, nationality, and club) that have awesome defending skills
14. Show wage records of the top 5 Players of the "Real Madrid" team
15. Show shooting records of the top 4 Players of the "Real Madrid" team
16. Show defending records of the top 5 Players of "Real Madrid" team
17. Show nationality records of top 5 Players of "Real Madrid" team
Note: Add comments wherever you find it necessary

Bonus: You can go beyond the scope of this project and find other results form this data set
"""
# Out:
# '\nData Project 1\n1. Load the csv file and show top 5 records from it\n2. How would you be able to see each column\'s name\n3. Showw the number of rows and columns in the dataset\n4. Show the number of platers in ech country.\n5. Create a bar plot of the top 5 countries with the highest number of platers, and fill the bars in green.\n6. Display the short name and wages for the top 5 players.\n7. Display the short name and wages for the top 5 players with the highest salaries.\n8. Create a bar plot of the previous bullet point.\n9. Show top 10 records for Germany.\n10. Show the top 5 records of Germnay players who have a maximum height, weight, and wage\n11. Display the short name and wages of the top 5 Germany players\n12. Show top 5 players who have the best shooting skills amoung all the players with short names.\n13. Show top 5 platers records (short name, defending, nationality, and club) that have awesome defending skills\n14. Show wage records of the top 5 Players of the "Real
# ...

# %%
import pandas as pd
import numpy as np

# %%
"""
1. Load the csv file and show top 5 records from it
"""
raw_df = pd.read_csv("players_20.csv")
raw_df.head() # returns the first 5 records from the dataset
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
"""
Data Cleaning
"""

df = raw_df.fillna(0)
df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
"""
2. How would you be able to see each column's name
"""
# for column in df.columns:
#   print(column)

print(list(df.columns), len(list(df.columns)))

#print(df.columns.values.tolist(), len(df.columns.values.tolist()))
# Out:
# ['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob', 'height_cm', 'weight_kg', 'nationality', 'club', 'overall', 'potential', 'value_eur', 'wage_eur', 'player_positions', 'preferred_foot', 'international_reputation', 'weak_foot', 'skill_moves', 'work_rate', 'body_type', 'real_face', 'release_clause_eur', 'player_tags', 'team_position', 'team_jersey_number', 'loaned_from', 'joined', 'contract_valid_until', 'nation_position', 'nation_jersey_number', 'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_reflexes', 'gk_speed', 'gk_positioning', 'player_traits', 'attacking_crossing', 'attacking_finishing', 'attacking_heading_accuracy', 'attacking_short_passing', 'attacking_volleys', 'skill_dribbling', 'skill_curve', 'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed', 'movement_agility', 'movement_reactions', 'movement_balance', 'power_shot_power', 'powe
# ...

# %%
"""
3. Show the number of rows and columns in the dataset
"""

#using built-on row and column length funcitons
print(f"This dataframe has {len(df)} rows and {len(df.columns)} columns.")

#using shape function
print(f"This dataframe has {df.shape[0]} rows and {df.shape[1]} columns.")
# Out:
# This dataframe has 18278 rows and 104 columns.
# This dataframe has 18278 rows and 104 columns.

# %%
"""
4. Show the number of players in each country.
"""
player_country = df[['nationality','short_name']].groupby(["nationality"]).size().reset_index(name="Total # of Players").sort_values("Total # of Players", ascending=False)
player_country
# Out:
#      nationality  Total # of Players
# 45       England                1667
# 57       Germany                1216
# 136        Spain                1035
# 53        France                 984
# 5      Argentina                 886
# ..           ...                 ...
# 96        Malawi                   1
# 100    Mauritius                   1
# 138     St Lucia                   1
# 135  South Sudan                   1
# 81        Jordan                   1
#
# [162 rows x 2 columns]

# %%
"""
5. Show the top 10 countries with the highest amount of players
"""
player_country.head(10)
# Out:
#      nationality  Total # of Players
# 45       England                1667
# 57       Germany                1216
# 136        Spain                1035
# 53        France                 984
# 5      Argentina                 886
# 18        Brazil                 824
# 77         Italy                 732
# 30      Colombia                 591
# 80         Japan                 453
# 108  Netherlands                 416

# %%
"""
6: Create a bar plot of the top 5 countries with the highest amount of players
"""
player_country5 = player_country.head()
total_players_plot = player_country5.plot.bar(x='nationality', y='Total # of Players', rot=45, color='green')

# %%
"""
7. Display the short name and wages for the top 5 players.
"""
wage_player = df[['short_name', 'wage_eur']].head()
wage_player
# Out:
#           short_name  wage_eur
# 0           L. Messi    565000
# 1  Cristiano Ronaldo    405000
# 2          Neymar Jr    290000
# 3           J. Oblak    125000
# 4          E. Hazard    470000

# %%
"""
7. Display the short name and wages for the top 5 players with the highest salaries.
"""
salary = wage_player
salary['salary_eur'] = (salary['wage_eur'] * 52).map('{:,.0f}'.format)
salary.sort_values('salary_eur', ascending=False)
# Out:
#           short_name  wage_eur  salary_eur
# 3           J. Oblak    125000   6,500,000
# 0           L. Messi    565000  29,380,000
# 4          E. Hazard    470000  24,440,000
# 1  Cristiano Ronaldo    405000  21,060,000
# 2          Neymar Jr    290000  15,080,000

# %%
"""
8. Create a bar plot of the previous bullet point.
"""
salary.plot.bar(x='short_name', y='wage_eur', rot=45)
# Out:
# <Axes: xlabel='short_name'>

# %%
"""
10. Show top 10 records for Germany.
"""
german=df.loc[(df['nationality'] == 'Germany')]
german.head(10)
# Out:
#      sofifa_id                                         player_url  \
# 6       192448  https://sofifa.com/player/192448/marc-andre-te...
# 31      167495  https://sofifa.com/player/167495/manuel-neuer/...
# 36      182521  https://sofifa.com/player/182521/toni-kroos/20...
# 37      188350  https://sofifa.com/player/188350/marco-reus/20...
# 49      178603  https://sofifa.com/player/178603/mats-hummels/...
# 55      222492  https://sofifa.com/player/222492/leroy-sane/20...
# 61      212622  https://sofifa.com/player/212622/joshua-kimmic...
# 70      189596  https://sofifa.com/player/189596/thomas-muller...
# 77      212190  https://sofifa.com/player/212190/niklas-sule/2...
# 109     235790  https://sofifa.com/player/235790/kai-havertz/2...
#
#         short_name              long_name  age         dob  height_cm  \
# 6    M. ter Stegen  Marc-André ter Stegen   27  1992-04-30        187
# 31        M. Neuer           Manuel Neuer   33  1986-03-27        193
# ...

# %%
"""
11. Show the top 5 records of Germnay players who have a maximum height, weight, and wage
"""
german_sort = german[['short_name', 'nationality', 'height_cm', 'weight_kg', 'wage_eur']].sort_values(['height_cm','weight_kg','wage_eur'], ascending=False).head()
german_sort
# Out:
#           short_name nationality  height_cm  weight_kg  wage_eur
# 8016       A. Seydel     Germany        199         90      9000
# 1389   L. Unnerstall     Germany        198        103     14000
# 1217        M. Esser     Germany        198         97     23000
# 13576   L. Watkowiak     Germany        197        103      2000
# 518      R. Fährmann     Germany        197         98     43000

# %%
"""
12. Display the short name and wages of the top 5 Germany players
"""
german[['short_name', 'wage_eur', 'overall']].sort_values(['overall'], ascending=False).head()
# Out:
#        short_name  wage_eur  overall
# 6   M. ter Stegen    250000       90
# 36       T. Kroos    330000       88
# 37        M. Reus    170000       88
# 31       M. Neuer    155000       88
# 49     M. Hummels    130000       87

# %%
"""
13. Show top 5 players who have the best shooting skills amoung all the players with short names.
"""
df[['short_name', 'shooting']].sort_values('shooting', ascending =False).head()
# Out:
#            short_name  shooting
# 1   Cristiano Ronaldo      93.0
# 0            L. Messi      92.0
# 12            H. Kane      91.0
# 17          S. Agüero      90.0
# 19          L. Suárez      89.0

# %%
"""
14. Show top 5 players records (short name, defending, nationality, and club) that have awesome defending skills
"""
df[['short_name', 'defending', 'nationality', 'club']].sort_values('defending', ascending=False).head()
# Out:
#       short_name  defending  nationality               club
# 16  G. Chiellini       90.0        Italy           Juventus
# 7    V. van Dijk       90.0  Netherlands          Liverpool
# 35      D. Godín       89.0      Uruguay              Inter
# 11  K. Koulibaly       89.0      Senegal             Napoli
# 49    M. Hummels       89.0      Germany  Borussia Dortmund

# %%
"""
15. Show wage records of the top 5 Players of the "Real Madrid" team
"""
# ordered by wage
df[['short_name','overall', 'wage_eur', 'club']].loc[(df['club'] == 'Real Madrid')].sort_values('wage_eur',ascending=False).head()

# ordered by overall value
# df[['short_name','overall', 'wage_eur', 'club']].loc[(df['club'] == 'Real Madrid')].sort_values('overall',ascending=False).head()
# Out:
#       short_name  overall  wage_eur         club
# 4      E. Hazard       91    470000  Real Madrid
# 8      L. Modrić       90    340000  Real Madrid
# 36      T. Kroos       88    330000  Real Madrid
# 18  Sergio Ramos       89    300000  Real Madrid
# 46    K. Benzema       87    285000  Real Madrid

# %%
"""
16. Show shooting records of the top 4 Players of the "Real Madrid" team
"""
# ordered by shooting
df[['short_name', 'shooting', 'club']].loc[(df['club'] == 'Real Madrid')].sort_values('shooting',ascending=False).head()

# ordered by overall 
#df[['short_name', 'shooting', 'club']].loc[(df['club'] == 'Real Madrid')].sort_values('overall',ascending=False).head()
# Out:
#        short_name  shooting         club
# 100       G. Bale      87.0  Real Madrid
# 106  J. Rodríguez      86.0  Real Madrid
# 4       E. Hazard      83.0  Real Madrid
# 46     K. Benzema      82.0  Real Madrid
# 161      L. Jović      82.0  Real Madrid

# %%
"""
17. Show defending records of the top 5 Players of "Real Madrid" team
"""
# ordered by defending
df[['short_name', 'defending', 'club']].loc[(df['club'] == 'Real Madrid')].sort_values('defending',ascending=False).head()

# ordered by overall 
#df[['short_name', 'defending', 'club']].loc[(df['club'] == 'Real Madrid')].sort_values('overall',ascending=False).head()
# Out:
#           short_name  defending         club
# 18      Sergio Ramos       87.0  Real Madrid
# 76         R. Varane       85.0  Real Madrid
# 42          Casemiro       85.0  Real Madrid
# 94          Carvajal       82.0  Real Madrid
# 277  Nacho Fernández       81.0  Real Madrid

# %%
"""
18. Show nationality records of top 5 Players of "Real Madrid" team
"""
df[['short_name', 'nationality', 'club', 'overall']].loc[(df['club'] == 'Real Madrid')].sort_values('overall',ascending=False).head()
# Out:
#       short_name nationality         club  overall
# 4      E. Hazard     Belgium  Real Madrid       91
# 8      L. Modrić     Croatia  Real Madrid       90
# 18  Sergio Ramos       Spain  Real Madrid       89
# 28   T. Courtois     Belgium  Real Madrid       88
# 36      T. Kroos     Germany  Real Madrid       88
